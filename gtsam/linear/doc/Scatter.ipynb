# %% [markdown]
# # Scatter

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/Scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `Scatter` collects non-zero entries into sparse structures. Notebook includes guarded examples and a numpy demonstration.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Example (numpy fallback)
#
# Show building a sparse-like structure using numpy arrays.

# %%
rows = [0,1,2]
cols = [0,2,1]
vals = [1.0, 2.0, 3.0]
print('COO-like arrays (numpy):')
print(rows, cols, vals)
(rows, cols, vals)
