# %% [markdown]
# # GaussianBayesTree

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/GaussianBayesTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `GaussianBayesTree` is a tree-structured representation of a Gaussian factorization used for efficient variable elimination and inference. This notebook mirrors the style of existing docs and provides guarded Python examples.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Creating a GaussianBayesTree
#
# Try constructing the object if bindings are present; otherwise describe expected usage.

# %%
try:
    gbt = gtsam.GaussianBayesTree()
except Exception as e:
    gbt = None
    print('GaussianBayesTree not available in Python bindings:', e)
gbt

# %% [markdown]
# ## Example (numpy fallback)
#
# Show a tiny example that demonstrates the effect of factor elimination using numpy linear solves.

# %%
A = np.array([[3.0, -1.0], [-1.0, 2.0]])
b = np.array([2.0, 1.0])
x = np.linalg.solve(A, b)
print('Example solve (numpy):', x)
x
