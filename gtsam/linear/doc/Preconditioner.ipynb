# %% [markdown]
# # Preconditioner

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/Preconditioner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `Preconditioner` builds preconditioners for iterative solvers. Notebook includes guarded examples and a simple diagonal preconditioner demo.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Diagonal preconditioner example
#
# Show a simple diagonal preconditioner using numpy.

# %%
A = np.array([[10.0, 1.0],[1.0,5.0]])
M_inv = np.diag(1.0/np.diag(A))
print('Diagonal preconditioner (M^-1):', M_inv)
M_inv
