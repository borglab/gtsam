# %% [markdown]
# # NoiseModel

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/NoiseModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `NoiseModel` describes noise assumptions used in factors (e.g., isotropic, diagonal). Notebook shows guarded examples and numpy equivalents.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Creating NoiseModels
#
# Try constructing available noise models in Python bindings; otherwise show simple covariance/precision examples.

# %%
try:
    nm = gtsam.noiseModel.Isotropic.Sigma(1, 0.1)
except Exception as e:
    nm = None
    print('noiseModel bindings not available:', e)
nm

# %% [markdown]
# ## Example (numpy fallback)
#
# Show a covariance matrix and its inverse (information matrix).

# %%
Sigma = np.array([[0.1, 0.0],[0.0,0.2]])
Info = np.linalg.inv(Sigma)
print('Information matrix (numpy):', Info)
Info
