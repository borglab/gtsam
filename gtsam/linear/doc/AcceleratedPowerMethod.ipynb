# %% [markdown]
# # AcceleratedPowerMethod

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/AcceleratedPowerMethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass  # Not running on Colab, do nothing

# %% [markdown]
# `AcceleratedPowerMethod` provides an accelerated approach to compute the dominant eigenvector/eigenvalue of a matrix-like operator. This notebook follows the style of other module docs and shows how to import, construct, and use the class in Python (when available).

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Creating an AcceleratedPowerMethod
#
# Constructing the object depends on the Python bindings available. Below is a guarded example that will show a placeholder message if the class is not exposed in Python.

# %%
# Example: guarded construction (may not be available in Python bindings)
try:
    apm = gtsam.AcceleratedPowerMethod()
except Exception as e:
    apm = None
    print('AcceleratedPowerMethod not available in Python bindings:', e)
apm

# %% [markdown]
# ## Operations and Examples
#
# Show basic usage patterns (if available). For example, running the solver on a small symmetric matrix to estimate the leading eigenvector.

# %%
# Small smoke example (pure numpy fallback)
A = np.array([[2.0, 0.5], [0.5, 1.0]])
w, v = np.linalg.eigh(A)
print('Largest eigenvalue (numpy):', w[-1])
v[:, -1]
:
,
: {
:
 },
: [
,
,
]
:
,
: {
:
 },
: [
-1
]
: {
: {
:
,
:
3
 },
: {
:
 } },
: 4,
: 5
