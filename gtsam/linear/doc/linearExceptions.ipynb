# %% [markdown]
# # linearExceptions

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/linearExceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `linearExceptions` declares exceptions used across the linear module. This notebook documents common error types and shows how to catch/handle them in Python bindings (guarded).

# %%
import gtsam
import numpy as np

# %% [markdown]
# ## Example: catching a hypothetical exception
#
# Demonstrate catching a linear module exception with a guarded call.

# %%
try:
    # Placeholder: call a function that may raise a linear exception
    raise RuntimeError('example linear exception')
except Exception as e:
    print('Caught exception:', e)
str(e)
