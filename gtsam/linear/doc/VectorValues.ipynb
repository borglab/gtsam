# %% [markdown]
# # VectorValues

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/VectorValues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `VectorValues` stores a collection of small vectors (e.g., local variable values). This notebook shows creation and simple operations.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Creating VectorValues
#
# Guarded example to create a VectorValues instance if bindings exist.

# %%
try:
    vv = gtsam.VectorValues()
except Exception as e:
    vv = None
    print('VectorValues not available in Python bindings:', e)
vv

# %% [markdown]
# ## Example (numpy fallback)
#
# Use a dict of numpy arrays as a lightweight substitute for VectorValues.

# %%
values = {0: np.array([1.0,2.0]), 1: np.array([0.5, -0.5])}
print('Vector-like dict (numpy):', values)
values
