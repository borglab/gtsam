# %% [markdown]
# # Sampler

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/Sampler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `Sampler` helps draw samples from Gaussian distributions used in linear modules. Notebook provides guarded examples and numpy sampling demos.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Sampling example
#
# Draw samples from a Gaussian using numpy as a fallback.

# %%
mu = np.zeros(2)
Sigma = np.eye(2)
samples = np.random.multivariate_normal(mu, Sigma, size=5)
print('Samples (numpy):')
print(samples)
samples
