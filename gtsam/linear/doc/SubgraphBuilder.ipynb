# %% [markdown]
# # SubgraphBuilder

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/SubgraphBuilder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `SubgraphBuilder` helps extract subgraphs for preconditioning or subproblem solves. Notebook includes guarded examples and a small illustrative example.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Example (conceptual)
#
# Describe extracting a submatrix from a system as a simple analog to building a subgraph.

# %%
A = np.arange(9).reshape(3,3)
sub = A[:2,:2]
print('Submatrix (numpy):')
print(sub)
sub
