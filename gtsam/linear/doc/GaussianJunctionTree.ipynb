# %% [markdown]
# # GaussianJunctionTree

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/linear/doc/GaussianJunctionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam
except ImportError:
    pass

# %% [markdown]
# `GaussianJunctionTree` implements junction-tree algorithms for Gaussian models. Notebook provides guarded examples and small demos.

# %%
import gtsam
import numpy as np
import graphviz

# %% [markdown]
# ## Creating a GaussianJunctionTree
#
# Try constructing the object if bindings exist; otherwise illustrate with numpy.

# %%
try:
    gjt = gtsam.GaussianJunctionTree()
except Exception as e:
    gjt = None
    print('GaussianJunctionTree not available in Python bindings:', e)
gjt

# %% [markdown]
# ## Example (numpy fallback)
#
# Solve a small linear system to demonstrate inference results.

# %%
A = np.array([[5.0, -2.0], [-2.0, 4.0]])
b = np.array([1.0, 0.5])
x = np.linalg.solve(A, b)
print('Example solve (numpy):', x)
x
