# %% [markdown]
# # SfmTrack2d
#
# > **Created by Codex.**
#
# Represent one landmark track as camera-indexed 2D observations.
#
# Source: [`SfmTrack.h`](https://github.com/borglab/gtsam/blob/develop/gtsam/sfm/SfmTrack.h)

# %% [markdown]
# GTSAM Copyright 2010-2026, Georgia Tech Research Corporation,
# Atlanta, Georgia 30332-0415
# All Rights Reserved
#
# Authors: Frank Dellaert, et al. (see THANKS for the full author list)
#
# See LICENSE for the license information

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/sfm/doc/SfmTrack2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    # %pip install --quiet gtsam-develop
except ImportError:
    pass

# %%
import gtsam
import numpy as np

from gtsam import symbol_shorthand

C = symbol_shorthand.C
K = symbol_shorthand.K
P = symbol_shorthand.P
S = symbol_shorthand.S
X = symbol_shorthand.X

# %% [markdown]
# ## Core operations
#
# Each measurement is `(camera_index, Point2)`. `measurementMatrix()` returns an `N x 2` array and `indexVector()` returns the corresponding camera indices. `siftIndex()` adds the feature position within the track for legacy code; it is not an external feature ID.

# %%
track = gtsam.SfmTrack2d()
track.addMeasurement(0, np.array([320.0, 240.0]))
track.addMeasurement(2, np.array([301.5, 241.0]))

print("measurements:", track.numberMeasurements())
print("camera indices:", track.indexVector())
print("image points:")
print(track.measurementMatrix())
print("unique cameras:", track.hasUniqueCameras())

# %% [markdown]
# ## Practical notes
#
# Camera indices refer to positions in an `SfmData` camera list, not arbitrary GTSAM keys. Use `gtsam.gtsfm.tracksFromPairwiseMatches` to assemble tracks from pairwise feature matches.
