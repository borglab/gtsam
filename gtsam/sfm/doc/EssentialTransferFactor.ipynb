# %% [markdown]
# # EssentialTransferFactor
#
# > **Created by Codex.**
#
# Transfer image points with two essential matrices and one fixed shared calibration.

# %% [markdown]
# GTSAM Copyright 2010-2026, Georgia Tech Research Corporation,
# Atlanta, Georgia 30332-0415
# All Rights Reserved
#
# Authors: Frank Dellaert, et al. (see THANKS for the full author list)
#
# See LICENSE for the license information

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/sfm/doc/EssentialTransferFactor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mathematical idea
#
# After calibration, a point $\tilde u_a$ defines an epipolar line in the target view,
#
# $$
# \ell_c^{(a)} \propto E_{ac}K^{-1}\tilde u_a,
# \qquad
# \ell_c^{(b)} \propto E_{bc}K^{-1}\tilde u_b,
# $$
#
# with transposes applied when an edge is stored in the opposite orientation. Their homogeneous intersection $\hat u_c\propto\ell_c^{(a)}\times\ell_c^{(b)}$ predicts the third observation; the factor returns its two-dimensional pixel residual after applying $K$.

# %%
try:
    import google.colab
    # %pip install --quiet gtsam-develop
except ImportError:
    pass

# %%
import gtsam
import numpy as np

from gtsam import symbol_shorthand

C = symbol_shorthand.C
K = symbol_shorthand.K
P = symbol_shorthand.P
S = symbol_shorthand.S
X = symbol_shorthand.X

# %% [markdown]
# ## Model
#
# This class calibrates the three image points, performs epipolar transfer with the two essential matrices, and uncalibrates the transferred point before computing pixel error. Calibration is fixed data owned by the factor.
#
# Python provides variants for `Cal3_S2`, `Cal3f`, and `Cal3Bundler`.

# %%
calibration = gtsam.Cal3_S2(500.0, 500.0, 0.0, 320.0, 240.0)
triplets = [(np.array([310.0, 235.0]),
             np.array([330.0, 236.0]),
             np.array([320.0, 235.5]))]
factor = gtsam.EssentialTransferFactorCal3_S2(
    gtsam.EdgeKey(0, 2), gtsam.EdgeKey(1, 2), triplets, calibration
)

print("factor keys:", factor.keys())
print("residual dimension:", factor.dim())
# Out:
# factor keys: [2, 4294967298]
# residual dimension: 2

# %% [markdown]
# ## Choosing the class
#
# Use this fixed-calibration version when all involved views share known intrinsics. Use `EssentialTransferFactorK` when calibration must be optimized jointly.

# %% [markdown]
# ## Source
#
# [`TransferFactor.h`](https://github.com/borglab/gtsam/blob/develop/gtsam/sfm/TransferFactor.h)
