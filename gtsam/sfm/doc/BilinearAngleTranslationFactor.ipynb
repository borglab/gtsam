# %% [markdown]
# # BilinearAngleTranslationFactor
#
# > **Created by Codex.**
#
# Use a per-edge scale variable to express a Bilinear Angle-based Translation Averaging (BATA) direction residual.

# %% [markdown]
# GTSAM Copyright 2010-2026, Georgia Tech Research Corporation,
# Atlanta, Georgia 30332-0415
# All Rights Reserved
#
# Authors: Frank Dellaert, et al. (see THANKS for the full author list)
#
# See LICENSE for the license information

# %% [markdown]
# <a href="https://colab.research.google.com/github/borglab/gtsam/blob/develop/gtsam/sfm/doc/BilinearAngleTranslationFactor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mathematical idea
#
# For translations $T_a,T_b\in\mathbb{R}^3$ and a measured unit direction $u_{ab}$, the factor introduces one inverse-baseline scale $s_{ab}$ and uses
#
# $$
# r_{ab} = |s_{ab}|(T_b-T_a)-u_{ab}.
# $$
#
# **BATA** means **Bilinear Angle-based Translation Averaging**. The auxiliary scale avoids differentiating the normalized baseline $(T_b-T_a)/\lVert T_b-T_a\rVert$. The formulation comes from [Zhuang, Cheong, and Lee, *Baseline Desensitizing in Translation Averaging*, IEEE/CVF Conference on Computer Vision and Pattern Recognition (CVPR), 2018](https://openaccess.thecvf.com/content_cvpr_2018/html/Zhuang_Baseline_Desensitizing_in_CVPR_2018_paper.html).

# %%
try:
    import google.colab
    # %pip install --quiet gtsam-develop
except ImportError:
    pass

# %%
import gtsam
import numpy as np

from gtsam import symbol_shorthand

C = symbol_shorthand.C
K = symbol_shorthand.K
P = symbol_shorthand.P
S = symbol_shorthand.S
X = symbol_shorthand.X

# %% [markdown]
# ## Model and availability
#
# The residual is `abs(scale) * (T_b - T_a) - measured_direction`. This avoids normalization and follows the Bilinear Angle-based Translation Averaging (BATA) formulation. Each observation needs its own scalar scale key.
#
# The class is currently C++-only. Python users obtain it through `LocationRecovery.buildGraph(edges, bilinear=True)`.

# %% [markdown]
# ## C++ example
#
# ~~~cpp
# #include <gtsam/sfm/TranslationFactor.h>
#
# using namespace gtsam;
#
# const auto noise = noiseModel::Isotropic::Sigma(3, 0.01);
# BilinearAngleTranslationFactor factor(
#     Symbol('t', 0), Symbol('t', 1), Symbol('S', 0),
#     Unit3(1.0, 0.0, 0.0), noise);
#
# const Vector3 residual = factor.evaluateError(
#     Point3(0, 0, 0), Point3(2, 0, 0), Vector1(0.5));
# // residual is zero because 0.5 * (2, 0, 0) == (1, 0, 0).
# ~~~
#
# Because sign is removed with `abs(scale)`, initialize scales away from zero for informative derivatives.

# %% [markdown]
# ## Source
#
# [`TranslationFactor.h`](https://github.com/borglab/gtsam/blob/develop/gtsam/sfm/TranslationFactor.h)
#
# Original BATA paper: [Zhuang, Cheong, and Lee, *Baseline Desensitizing in Translation Averaging*, IEEE/CVF Conference on Computer Vision and Pattern Recognition (CVPR), 2018](https://openaccess.thecvf.com/content_cvpr_2018/html/Zhuang_Baseline_Desensitizing_in_CVPR_2018_paper.html).
